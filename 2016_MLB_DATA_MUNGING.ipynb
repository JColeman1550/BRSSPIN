# %% [markdown]
# <a href="https://colab.research.google.com/github/JColeman1550/BASEBALL/blob/main/2016_MLB_DATA_MUNGING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('chained_assignment', None)

# %%
# %%capture
# %pip install pybaseball
import pybaseball as pyb

# %%
df_2016 = pyb.batting_stats(2016)

df_2016 = df_2016.loc[:, :'WAR']

df_2016.head()
# Out:
#      IDfg  Season            Name Team  Age    G   AB   PA    H   1B  2B  3B  \
# 1   10155    2016      Mike Trout  LAA   24  159  549  681  173  107  32   5
# 16  13611    2016    Mookie Betts  BOS   23  158  672  730  214  136  42   5
# 7   15429    2016     Kris Bryant  CHC   24  155  603  699  176   99  35   3
# 4    5038    2016  Josh Donaldson  TOR   30  155  577  700  164   90  32   5
# 21  13624    2016    Corey Seager  LAD   22  157  627  687  193  122  40   5
#
#     HR    R  RBI   BB  IBB   SO  HBP  SF  SH  GDP  SB  CS    AVG   GB   FB  \
# 1   29  123  100  116   12  137   11   5   0    5  30   7  0.315  172  153
# 16  31  122  113   49    1   80    2   7   0   12  26   4  0.318  247  235
# 7   39  121  102   75    5  154   18   3   0    3   8   5  0.292  138  207
# 4   37  122   99  109    6  119    9   3   2   16   7   1  0.284  176  187
# 21  26  105   72   54    5  133    4   2   0   12   3   3  0.308  229  145
#
# ...

# %%
df_2016.tail()
# Out:
#       IDfg  Season             Name   Team  Age    G   AB   PA    H   1B  2B  \
# 98    3516    2016      Eric Hosmer    KCR   26  158  605  667  161  111  24
# 116  10339    2016  Scooter Gennett    MIL   26  136  498  542  131   86  30
# 127   3086    2016   Mitch Moreland    TEX   30  147  460  503  107   64  21
# 134   2530    2016    Yonder Alonso    OAK   29  156  482  532  122   81  34
# 144   5133    2016   Alexei Ramirez  - - -   34  145  478  506  115   85  22
#
#      3B  HR   R  RBI  BB  IBB   SO  HBP  SF  SH  GDP  SB  CS    AVG   GB   FB  \
# 98    1  25  80  104  57    5  132    1   4   0   18   5   3  0.266  279  117
# 116   1  14  58   56  38    1  114    2   2   1   11   8   1  0.263  172  133
# 127   0  22  49   60  35    5  118    8   0   0    8   1   0  0.233  142  128
# 134   0   7  52   56  45    1   74    1   4   0   15   3   1  0.253  180  136
# 144   2   6  38   48  21    3   63    4   2   1    8   8   9  0.241  215  117
#
# ...
